# %% [markdown]
# ![Data Integration Diagram](/Volumes/dev_project/bronze/source_system/Data_integration.drawio.png)

# %%
from IPython.display import Image, display

path = "/Volumes/dev_project/bronze/source_system/Data_integration.drawio.png"
display(Image(path))
