# %%
from IPython.display import Image, display

path = "/Volumes/dev_project/bronze/source_system/Lakehouse_Architecture.drawio.png"
display(Image(path))

# %% [markdown]
# ![Lakehouse_Architecture](/Volumes/dev_project/bronze/source_system/Lakehouse_Architecture.drawio.png)
