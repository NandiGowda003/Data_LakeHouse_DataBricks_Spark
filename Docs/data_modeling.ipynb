# %%
from IPython.display import Image, display

path = "/Volumes/dev_project/bronze/source_system/data_Model_StarSchema.png"
display(Image(path))

# %% [markdown]
# ![data_Model_StarSchema](/Volumes/dev_project/bronze/source_system/data_Model_StarSchema.png)
